# %% [markdown]
# #LLM Chatbot Project

# %% [markdown]
# This notebook uses Google Drive to store the vector embeddings and code. Keep the embeddings and code in LLM_Chatbot folder at the root of your Google Drive.

# %% [markdown]
# **Before you start!**
#
# * To run this notebook use T4 GPU. You can select this runtime from
#
#   * Open **Runtime > Change runtime type** from Menu
#   * Select **T4 GPU** option in **Hardware accelerator** section

# %%
from IPython.display import clear_output

# %% [markdown]
# **Download the Ollama in Google Colab**

# %%
# !curl https://ollama.ai/install.sh | sh

clear_output()

# %% [markdown]
# **Download and Install GPU Drivers**

# %%
# !echo 'debconf debconf/frontend select Noninteractive' | sudo debconf-set-selections
# !sudo apt-get update && sudo apt-get install -y cuda-drivers

clear_output()

# %% [markdown]
# **Start Ollama in notebook and pull the models**

# %%
# !OLLAMA_HOST=0.0.0.0

# %%
import subprocess
subprocess.Popen(["ollama", "serve"]) # start ollama in background
# Out:
# <Popen: returncode: None args: ['ollama', 'serve']>

# %%
# !ollama pull llama3.1:latest
# Out:
# Streaming output truncated to the last 5000 lines.
# pulling 09cd6813dc2e... 100% ▕▏  16 GB
# pulling 73b313b5552d... 100% ▕▏ 1.4 KB
# pulling 0ba8f0e314b4... 100% ▕▏  12 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling daa7d15f6d0b... 100% ▕▏  484 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 09cd6813dc2e... 100% ▕▏  16 GB
# pulling 73b313b5552d... 100% ▕▏ 1.4 KB
# pulling 0ba8f0e314b4... 100% ▕▏  12 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling daa7d15f6d0b... 100% ▕▏  484 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 09cd6813dc2e... 100% ▕▏  16 GB
# pulling 73b313b5552d... 100% ▕▏ 1.4 KB
# pulling 0ba8f0e314b4... 100% ▕▏  12 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling daa7d15f6d0b... 100% ▕▏  484 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 09cd6813dc2e... 100% ▕▏  16 GB
# pulling 73b313b5552d... 100% ▕▏ 1.4 KB
# pulling 0ba8f0e314b4... 100% ▕▏  12 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# ...

# %% [markdown]
# **Connect to Google Drive**

# %%
# let colab access to google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Install Project Requirements**

# %%
# !pip install -r /content/drive/MyDrive/LLM_Chatbot/requirements.txt

clear_output()

# %% [markdown]
# **Install Localtunnel**

# %%
# !npm install localtunnel

clear_output()

# %% [markdown]
# **Run the streamlit app locally**

# %%
# !streamlit run /content/drive/MyDrive/LLM_Chatbot/open_banking_api_chatbot_v2.py --server.address=localhost &>/content/logs.txt &

# %% [markdown]
# **Expose the app using localtunnel**

# %%
# !npx localtunnel --port 8501 & echo "Use this password for tunnel password: $(curl -s ipv4.icanhazip.com)"
# Out:
# Use this password for tunnel password: 34.124.247.43
# your url is: https://open-owls-leave.loca.lt
